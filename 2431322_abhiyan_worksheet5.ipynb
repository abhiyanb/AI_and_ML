# %% [markdown]
# ### Amazon Fruits Dataset

# %% [markdown]
# ## Task 1: Data Understanding and Visualization

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import zipfile
import os

zip_file_path = '/content/drive/MyDrive/AI and ML/week5/Copy of FruitinAmazon.zip'
extraction_path = './'

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_path)

print(f"'{zip_file_path}' unzipped to '{extraction_path}' successfully.")
print(f"Contents of the extraction directory: {os.listdir(extraction_path)}")
# Out:
# '/content/drive/MyDrive/AI and ML/week5/Copy of FruitinAmazon.zip' unzipped to './' successfully.
# Contents of the extraction directory: ['.config', 'drive', 'FruitinAmazon', 'sample_data']

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from PIL import Image
from sklearn.metrics import classification_report

train_dir = '/content/FruitinAmazon/train'
test_dir  = '/content/FruitinAmazon/test'

# %%
# Task 1.1 - Visualise one random image per class in a 2-row grid
class_dirs = sorted(os.listdir(train_dir))
num_classes = len(class_dirs)

cols = (num_classes + 1) // 2
fig, axes = plt.subplots(2, cols, figsize=(cols * 4, 8))
axes = axes.flatten()

for i, cls in enumerate(class_dirs):
    cls_path = os.path.join(train_dir, cls)
    images = os.listdir(cls_path)
    img_path = os.path.join(cls_path, random.choice(images))
    img = Image.open(img_path)
    axes[i].imshow(img)
    axes[i].set_title(cls)
    axes[i].axis('off')

for j in range(i + 1, len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

print(f"Classes found: {class_dirs}")
print("Observation: Images vary in size, background, and lighting across classes.")
# Out:
# Classes found: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']
# Observation: Images vary in size, background, and lighting across classes.

# %%
# Task 1.2 - Check for and remove corrupted images
corrupted = []

for cls in class_dirs:
    cls_path = os.path.join(train_dir, cls)
    for fname in os.listdir(cls_path):
        img_path = os.path.join(cls_path, fname)
        try:
            img = Image.open(img_path)
            img.verify()
        except (IOError, SyntaxError):
            corrupted.append(img_path)
            os.remove(img_path)
            print(f"Removed corrupted image: {img_path}")

if not corrupted:
    print("No Corrupted Images Found.")
# Out:
# No Corrupted Images Found.

# %% [markdown]
# ## Task 2: Loading and Preprocessing Image Data

# %%
# Hyperparameters
img_height      = 128
img_width       = 128
batch_size      = 16
validation_split = 0.2

# Normalise pixel values to [0, 1]
rescale = tf.keras.layers.Rescaling(1./255)

# Training dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=True,
    validation_split=validation_split,
    subset='training',
    seed=123
)
train_ds = train_ds.map(lambda x, y: (rescale(x), y))

# Validation dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=False,
    validation_split=validation_split,
    subset='validation',
    seed=123
)
val_ds = val_ds.map(lambda x, y: (rescale(x), y))

# Test dataset
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=False
)
test_ds = test_ds.map(lambda x, y: (rescale(x), y))

print(f"Number of classes: {num_classes}")
# Out:
# Found 90 files belonging to 6 classes.
# Using 72 files for training.
# Found 90 files belonging to 6 classes.
# Using 18 files for validation.
# Found 30 files belonging to 6 classes.
# Number of classes: 6

# %% [markdown]
# ## Task 3: Build the CNN Model

# %%
# CNN architecture
model = keras.Sequential([

    # Conv Block 1
    layers.Conv2D(32, (3, 3), padding='same', activation='relu',
                  input_shape=(img_height, img_width, 3)),
    layers.MaxPooling2D((2, 2), strides=2),

    # Conv Block 2
    layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
    layers.MaxPooling2D((2, 2), strides=2),

    # Flatten and fully connected layers
    layers.Flatten(),
    layers.Dense(128, activation='relu'),  # hidden layer 1
    layers.Dense(64,  activation='relu'),  # hidden layer 2

    # Output layer
    layers.Dense(num_classes, activation='softmax')
])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     4,194,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,213,222 (16.07 MB)
#  Trainable params: 4,213,222 (16.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Task 4: Compile and Train the Model

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Callbacks: save best model and stop early if no improvement
checkpoint_cb = keras.callbacks.ModelCheckpoint(
    'best_model.h5',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

early_stop_cb = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True,
    verbose=1
)

history = model.fit(
    train_ds,
    epochs=300,
    validation_data=val_ds,
    callbacks=[checkpoint_cb, early_stop_cb]
)
# Out:
# Epoch 1/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.1080 - loss: 2.0741
# Epoch 1: val_accuracy improved from None to 0.00000, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to best_model.h5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 398ms/step - accuracy: 0.1389 - loss: 2.1658 - val_accuracy: 0.0000e+00 - val_loss: 1.6764
# Epoch 2/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.2601 - loss: 1.6677
# Epoch 2: val_accuracy improved from 0.00000 to 0.38889, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 2: finished saving model to best_model.h5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 328ms/step - accuracy: 0.2639 - loss: 1.6451 - val_accuracy: 0.3889 - val_loss: 1.7014
# Epoch 3/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.3219 - loss: 1.5997
# Epoch 3: val_accuracy improved from 0.38889 to 0.83333, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 3: finished saving model to best_model.h5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 371ms/step - accuracy: 0.3750 - loss: 1.5282 - val_accuracy: 0.8333 - val_loss: 1.1946
# Epoch 4/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.6076 - loss: 1.2565
# Epoch 4: val_accuracy did not improve from 0.83333
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 309ms/step - accuracy: 0.6111 - loss: 1.2184 - val_accuracy: 0.7222 - val_loss: 1.0541
# Epoch 5/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.7378 - loss: 0.8910
# Epoch 5: val_accuracy did not improve from 0.83333
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 405ms/step - accuracy: 0.7778 - loss: 0.8631 - val_accuracy: 0.7222 - val_loss: 0.8149
# Epoch 6/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - accuracy: 0.8649 - loss: 0.5719
# Epoch 6: val_accuracy did not improve from 0.83333
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 538ms/step - accuracy: 0.8611 - loss: 0.5678 - val_accuracy: 0.7222 - val_loss: 1.0499
# Epoch 7/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.8865 - loss: 0.4241
# Epoch 7: val_accuracy improved from 0.83333 to 0.88889, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 7: finished saving model to best_model.h5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 440ms/step - accuracy: 0.8750 - loss: 0.4500 - val_accuracy: 0.8889 - val_loss: 0.3457
# Epoch 8/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9573 - loss: 0.2725
# Epoch 8: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 309ms/step - accuracy: 0.9583 - loss: 0.2223 - val_accuracy: 0.7778 - val_loss: 0.6481
# Epoch 9/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9899 - loss: 0.0925
# Epoch 9: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 299ms/step - accuracy: 0.9861 - loss: 0.1001 - val_accuracy: 0.7778 - val_loss: 0.6946
# Epoch 10/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 1.0000 - loss: 0.0347
# Epoch 10: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 305ms/step - accuracy: 1.0000 - loss: 0.0347 - val_accuracy: 0.8889 - val_loss: 0.5040
# Epoch 11/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9899 - loss: 0.0342
# Epoch 11: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 312ms/step - accuracy: 0.9861 - loss: 0.0399 - val_accuracy: 0.8889 - val_loss: 0.3820
# Epoch 12/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 1.0000 - loss: 0.0140
# Epoch 12: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 540ms/step - accuracy: 1.0000 - loss: 0.0121 - val_accuracy: 0.8333 - val_loss: 0.4818
# Epoch 13/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 13: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 535ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.7778 - val_loss: 0.7518
# Epoch 14/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 14: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 317ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.7778 - val_loss: 0.7799
# Epoch 15/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 15: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 315ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.8333 - val_loss: 0.6680
# Epoch 16/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 16: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 302ms/step - accuracy: 1.0000 - loss: 9.7908e-04 - val_accuracy: 0.8889 - val_loss: 0.6091
# Epoch 17/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 1.0000 - loss: 7.8800e-04
# Epoch 17: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 303ms/step - accuracy: 1.0000 - loss: 8.6419e-04 - val_accuracy: 0.8889 - val_loss: 0.5688
# Epoch 18/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 1.0000 - loss: 7.0597e-04
# Epoch 18: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 300ms/step - accuracy: 1.0000 - loss: 7.5404e-04 - val_accuracy: 0.8889 - val_loss: 0.5459
# Epoch 19/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 1.0000 - loss: 7.0174e-04
# Epoch 19: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 306ms/step - accuracy: 1.0000 - loss: 6.0926e-04 - val_accuracy: 0.8889 - val_loss: 0.5384
# Epoch 20/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 1.0000 - loss: 5.6374e-04
# Epoch 20: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 503ms/step - accuracy: 1.0000 - loss: 4.8573e-04 - val_accuracy: 0.8889 - val_loss: 0.5613
# Epoch 21/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 1.0000 - loss: 3.8864e-04
# Epoch 21: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 542ms/step - accuracy: 1.0000 - loss: 4.1085e-04 - val_accuracy: 0.8889 - val_loss: 0.5867
# Epoch 22/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 1.0000 - loss: 3.0099e-04
# Epoch 22: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 313ms/step - accuracy: 1.0000 - loss: 3.6815e-04 - val_accuracy: 0.8889 - val_loss: 0.6188
# Epoch 23/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 1.0000 - loss: 3.1201e-04
# Epoch 23: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 316ms/step - accuracy: 1.0000 - loss: 3.2378e-04 - val_accuracy: 0.8889 - val_loss: 0.6458
# Epoch 24/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 1.0000 - loss: 3.0866e-04
# Epoch 24: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 318ms/step - accuracy: 1.0000 - loss: 2.9224e-04 - val_accuracy: 0.8889 - val_loss: 0.6747
# Epoch 25/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 1.0000 - loss: 2.8742e-04
# Epoch 25: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 313ms/step - accuracy: 1.0000 - loss: 2.7001e-04 - val_accuracy: 0.8889 - val_loss: 0.6923
# Epoch 26/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 1.0000 - loss: 2.1604e-04
# Epoch 26: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 307ms/step - accuracy: 1.0000 - loss: 2.5319e-04 - val_accuracy: 0.8889 - val_loss: 0.7011
# Epoch 27/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 1.0000 - loss: 2.9709e-04
# Epoch 27: val_accuracy did not improve from 0.88889
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 354ms/step - accuracy: 1.0000 - loss: 2.4082e-04 - val_accuracy: 0.8889 - val_loss: 0.7055
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 7.

# %% [markdown]
# ## Visualisation: Training & Validation Loss/Accuracy

# %%
# Plot training curves
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Accuracy
axes[0].plot(history.history['accuracy'],     label='Train Accuracy')
axes[0].plot(history.history['val_accuracy'], label='Val Accuracy')
axes[0].set_title('Model Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Loss
axes[1].plot(history.history['loss'],     label='Train Loss')
axes[1].plot(history.history['val_loss'], label='Val Loss')
axes[1].set_title('Model Loss')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 5: Evaluate the Model

# %%
test_loss, test_acc = model.evaluate(test_ds)
print(f"Test Loss:     {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5333 - loss: 1.1978
# Test Loss:     1.1978
# Test Accuracy: 0.5333

# %% [markdown]
# ## Task 6: Save and Load the Model

# %%
model.save('cnn_fruits_model.h5')
print("Model saved as cnn_fruits_model.h5")

loaded_model = keras.models.load_model('cnn_fruits_model.h5')
loss, acc = loaded_model.evaluate(test_ds)
print(f"Loaded Model - Test Loss: {loss:.4f} | Test Accuracy: {acc:.4f}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as cnn_fruits_model.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.5333 - loss: 1.1978
# Loaded Model - Test Loss: 1.1978 | Test Accuracy: 0.5333

# %% [markdown]
# ## Task 7: Predictions and Classification Report

# %%
# Collect all true labels and predictions from test set
y_true, y_pred = [], []

for images, labels in test_ds:
    preds = loaded_model.predict(images, verbose=0)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(labels.numpy())

print(classification_report(y_true, y_pred, target_names=class_dirs))
# Out:
#               precision    recall  f1-score   support
#
#         acai       0.62      1.00      0.77         5
#      cupuacu       0.50      1.00      0.67         5
#     graviola       1.00      0.40      0.57         5
#      guarana       1.00      0.40      0.57         5
#      pupunha       0.00      0.00      0.00         5
#       tucuma       0.25      0.40      0.31         5
#
#     accuracy                           0.53        30
#    macro avg       0.56      0.53      0.48        30
# weighted avg       0.56      0.53      0.48        30
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
